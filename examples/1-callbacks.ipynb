# %% [markdown]
# # GPSO optimisation example with callbacks
#
# This notebook shows the usage of callbacks during optimisation for the better experience!

# %%
# imports
import os
import numpy as np
import matplotlib.pyplot as plt
from shutil import rmtree
import logging
from gpflow.utilities import print_summary

from gpso import ParameterSpace, GPSOptimiser
from gpso.optimisation import CallbackTypes, GPSOCallback
from gpso.callbacks import (
    PostIterationPlotting,
    PostUpdateLogging,
    PreFinaliseSave,
    GPFlowCheckpoints,
)
from gpso.utils import set_logger, make_dirs

plt.style.use("seaborn-poster")

# %% [markdown]
# We will use the same objective function as before, so no surprises there.

# %%
# define objective function - compare with paper Fig. 2
def obj(point, offset=0.0, rotate=True):
    x, y = point
    if rotate:
        ct = np.cos(np.pi / 4)
        st = np.sin(np.pi / 4)
        xn = ct * x + st * y
        yn = ct * y - st * x
        x = xn
        y = yn
    return (
        3 * (1 - x) ** 2.0 * np.exp(-(x ** 2) - (y + 1) ** 2)
        - 10 * (x / 5.0 - x ** 3 - y ** 5) * np.exp(-(x ** 2) - y ** 2)
        - 1 / 3 * np.exp(-((x + 1) ** 2) - y ** 2)
        - offset
    )


# bounds of the parameters we will optimise
x_bounds = [-3, 5]
y_bounds = [-3, 3]
# number of points per dimension for plotting
N_POINTS = 120

# %% [markdown]
# Definition of parameter space is the same as previously

# %%
space = ParameterSpace(
    parameter_names=["x", "y"], parameter_bounds=[x_bounds, y_bounds]
)

# %% [markdown]
# Now for the changes!
#
# ### Callbacks
# `pyGPSO` supports so-called callbacks. They are functions which run regularly after some events. Currently there exist 5 types of callbacks:
# * **post-initialise callback**: runs just once, after initialisation of the problem
# * **pre-iteration callback**: runs repeatedly just before the iteration loop
# * **post-iteration callback**: runs repeatedly just after the iteration loop
# * **post-update callback**: runs after each update of GPR
# * **pre-finalise callback**: runs just once, just before the optimisation is finished
#
# `pyGPSO` comes with 4 already defined, hopefully useful, callbacks. However, they are very easy to create for yourself as we will see in a moment! Let's first check the predefined callbacks:

# %% [markdown]
# #### `PostIterationPlotting` callback
# Simple - plots conditional surrogate distribution, marginal parameter distribution and ternary tree after each iteration, so you can visually check the convergence of the algorithm

# %%
plotting_dir = "output"
make_dirs(plotting_dir)

plotting_callback = PostIterationPlotting(
    filename_pattern=os.path.join(plotting_dir, "post_iter_plot"),
    plot_ext=".png",
    gp_mean_limits=[-10, 10],
    gp_var_limits=[0, 5],
    marginal_plot_type="kde",
    marginal_percentile=0.5,  # low percentile - just for showcase
    from_iteration=10,  # from 10th iteration, we do not care about first 4...
)

# %% [markdown]
# #### `PostUpdateLogging` callback
# Even simpler callback - after each GPR update logs the current hyperparameters of GP regressor

# %%
gp_logger = PostUpdateLogging()

# %% [markdown]
# #### `PreFinaliseSave` callback
# This callback saves parameter space (and its state, i.e. leaves) and GPR surrogate together with list of points that were either evaluated or (as centers of leaves) estimated.

# %%
fin_saver = PreFinaliseSave(path=plotting_dir)

# %% [markdown]
# #### `GPFlowCheckpoints` callback
# This callback saves checkpoints of the GPR model after each update. As such it might not be useful, but can be easily altered to provide more functionality, e.g. restoring GPR model on the go.

# %%
checkpoints = GPFlowCheckpoints(path=plotting_dir, max_to_keep=3)

# %% [markdown]
# ### Create your own callback!
# OK, nice, you got me hooked, right? But I do not like your callbacks, I'd like to create my own!
#
# Well, no problemo! Lets say, you want a callback that will plot surface of GPR after each GPR update. Lets start!

# %%
# we will subclass base callback
class GPRPlotSurface(GPSOCallback):
    # define type of callback - post-update
    callback_type = CallbackTypes.post_update

    # do all settings here!
    def __init__(self, path):
        # always super init for a sanity check and validation
        super().__init__()
        self.path = path
        # set plotting data
        x = np.linspace(x_bounds[0], x_bounds[1], N_POINTS)
        y = np.linspace(y_bounds[0], y_bounds[1], N_POINTS)
        x, y = np.meshgrid(x, y)
        self.stk = np.hstack([x.reshape((-1, 1)), y.reshape((-1, 1))])
        self.im_shape = x.shape
        self.counter = 0

    # this will be actually run when a callback is called
    # always only one argument - optimiser class itself
    def run(self, optimiser):
        # always super run for a sanity check and validation
        super().run(optimiser)
        # actual plotting
        plt.figure()
        mean, _ = optimiser.gp_surr.gpr_model.predict_y(
            optimiser.param_space.normalise_coords(self.stk)
        )
        mean = mean.numpy().reshape(self.im_shape)
        plt.imshow(
            mean, vmax=8.0, vmin=-8.0, cmap=plt.get_cmap("cividis"), origin="lower"
        )
        cbar = plt.colorbar()
        cbar.set_label("Objective-GP")
        plt.title("Surrogate surface")
        plt.savefig(os.path.join(self.path, f"surr_surface_{self.counter}.png"))
        plt.close()
        self.counter += 1


# now we need to init our brand new callback
surr_surface = GPRPlotSurface(path=plotting_dir)

# %% [markdown]
# ### Run with callbacks
# After we initialise our callbacks, we run the optimiser as usual and just pass all callbacks as a list

# %%
opt = GPSOptimiser(
    parameter_space=space,
    exploration_method="tree",
    exploration_depth=5,
    update_cycle=1,
    budget=50,
    stopping_condition="evaluations",
    gp_lik_sigma=1.0e-3,
    n_workers=4,
    callbacks=[plotting_callback, gp_logger, fin_saver, checkpoints, surr_surface],
)

# %%
# log_level INFO: reasonable amount of information on what is happening
# log_level DEBUG: a lot of information on what is happening
set_logger(log_level=logging.INFO)
# run vanilla, with default initialisation and just 1 repetition of objective function (since it's deterministic...)
best_point = opt.run(obj)
# Out:
# [2020-03-31 16:58:12] INFO: Starting 2-dimensional optimisation with budget of 50 objective function evaluations...
# [2020-03-31 16:58:12] INFO: Sampling 2 vertices per dimension within L1 ball of 0.25 of the domain size radius in normalised coordinates using 4 worker(s)...
# [2020-03-31 16:58:12] INFO: Update step: retraining GP model and updating scores...
# [2020-03-31 16:58:15] INFO: Running PostUpdateLogging callback...
# [2020-03-31 16:58:15] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype    value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ---------------------
# GPR.mean_function.c      Parameter                             True         ()       float64  -0.9939317375330878
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  6.7919674692889
# GPR.kernel.lengthscales  Parameter  Softplus                   True         (1,)     float64  [0.36047938]
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.048315485555379e-06
# [2020-03-31 16:58:15] INFO: Running GPFlowCheckpoints callback...
# [2020-03-31 16:58:15] INFO: Running GPRPlotSurface callback...
# [2020-03-31 16:58:15] INFO: Exploration step: sampling children in the ternary tree...
# [2020-03-31 16:58:15] INFO: Selecting step: evaluating best leaves...
# [2020-03-31 16:58:15] INFO: Update step: retraining GP model and updating scores...
# [2020-03-31 16:58:16] INFO: Running PostUpdateLogging callback...
# [2020-03-31 16:58:16] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype    value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ----------------------
# GPR.mean_function.c      Parameter                             True         ()       float64  -0.4684727526153909
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  6.189678513425054
# GPR.kernel.lengthscales  Parameter  Softplus                   True         (1,)     float64  [0.33173198]
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.0483154640170533e-06
# [2020-03-31 16:58:16] INFO: Running GPFlowCheckpoints callback...
# [2020-03-31 16:58:16] INFO: Running GPRPlotSurface callback...
# [2020-03-31 16:58:16] INFO: After 1th iteration:
# 	 number of obj. func. evaluations: 6
# 	 highest score: 2.019346080880167
# 	 highest UCB: 0.5464137300580307
# [2020-03-31 16:58:16] INFO: Running PostIterationPlotting callback...
# [2020-03-31 16:58:16] INFO: Exploration step: sampling children in the ternary tree...
# [2020-03-31 16:58:16] INFO: Selecting step: evaluating best leaves...
# [2020-03-31 16:58:16] INFO: Update step: retraining GP model and updating scores...
# [2020-03-31 16:58:16] INFO: Running PostUpdateLogging callback...
# [2020-03-31 16:58:16] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype    value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ----------------------
# GPR.mean_function.c      Parameter                             True         ()       float64  -0.5856266206695224
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  4.646463600946673
# GPR.kernel.lengthscales  Parameter  Softplus                   True         (1,)     float64  [0.29387037]
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.0483154531368683e-06
# [2020-03-31 16:58:16] INFO: Running GPFlowCheckpoints callback...
# [2020-03-31 16:58:16] INFO: Running GPRPlotSurface callback...
# [2020-03-31 16:58:17] INFO: After 2th iteration:
# 	 number of obj. func. evaluations: 7
# 	 highest score: 2.019346080880167
# 	 highest UCB: 3.883138246958915
# [2020-03-31 16:58:17] INFO: Running PostIterationPlotting callback...
# [2020-03-31 16:58:17] INFO: Exploration step: sampling children in the ternary tree...
# [2020-03-31 16:58:17] INFO: Selecting step: evaluating best leaves...
# [2020-03-31 16:58:17] INFO: Update step: retraining GP model and updating scores...
# [2020-03-31 16:58:17] INFO: Running PostUpdateLogging callback...
# [2020-03-31 16:58:17] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype    value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ----------------------
# GPR.mean_function.c      Parameter                             True         ()       float64  -0.22863654356882787
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  2.5812935822062597
# GPR.kernel.lengthscales  Parameter  Softplus                   True         (1,)     float64  [0.18603789]
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.0483154196081344e-06
# [2020-03-31 16:58:17] INFO: Running GPFlowCheckpoints callback...
# [2020-03-31 16:58:17] INFO: Running GPRPlotSurface callback...
# [2020-03-31 16:58:17] INFO: After 3th iteration:
# 	 number of obj. func. evaluations: 9
# 	 highest score: 2.019346080880167
# 	 highest UCB: 3.5729359051551524
# [2020-03-31 16:58:17] INFO: Running PostIterationPlotting callback...
# [2020-03-31 16:58:17] INFO: Exploration step: sampling children in the ternary tree...
# [2020-03-31 16:58:18] INFO: Selecting step: evaluating best leaves...
# [2020-03-31 16:58:18] INFO: Update step: retraining GP model and updating scores...
# [2020-03-31 16:58:18] INFO: Running PostUpdateLogging callback...
# [2020-03-31 16:58:18] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype    value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ---------------------
# GPR.mean_function.c      Parameter                             True         ()       float64  -0.17645620385161823
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  1.9015323713196797
# GPR.kernel.lengthscales  Parameter  Softplus                   True         (1,)     float64  [0.13146083]
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.048315420940402e-06
# [2020-03-31 16:58:18] INFO: Running GPFlowCheckpoints callback...
# [2020-03-31 16:58:18] INFO: Running GPRPlotSurface callback...
# [2020-03-31 16:58:18] INFO: After 4th iteration:
# 	 number of obj. func. evaluations: 12
# 	 highest score: 2.019346080880167
# 	 highest UCB: 3.2598991628698375
# [2020-03-31 16:58:18] INFO: Running PostIterationPlotting callback...
# [2020-03-31 16:58:18] INFO: Exploration step: sampling children in the ternary tree...
# [2020-03-31 16:58:19] INFO: Selecting step: evaluating best leaves...
# [2020-03-31 16:58:19] INFO: Update step: retraining GP model and updating scores...
# [2020-03-31 16:58:19] INFO: Running PostUpdateLogging callback...
# [2020-03-31 16:58:19] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype    value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ----------------------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.07026393922058627
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  4.948868327712383
# GPR.kernel.lengthscales  Parameter  Softplus                   True         (1,)     float64  [0.14816661]
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.0483153352311888e-06
# [2020-03-31 16:58:19] INFO: Running GPFlowCheckpoints callback...
# [2020-03-31 16:58:19] INFO: Running GPRPlotSurface callback...
# [2020-03-31 16:58:19] INFO: After 5th iteration:
# 	 number of obj. func. evaluations: 15
# 	 highest score: 6.822127355673395
# 	 highest UCB: 7.162332354239675
# [2020-03-31 16:58:19] INFO: Running PostIterationPlotting callback...
# [2020-03-31 16:58:19] INFO: Exploration step: sampling children in the ternary tree...
# [2020-03-31 16:58:20] INFO: Selecting step: evaluating best leaves...
# [2020-03-31 16:58:20] INFO: Update step: retraining GP model and updating scores...
# [2020-03-31 16:58:20] INFO: Running PostUpdateLogging callback...
# [2020-03-31 16:58:20] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype    value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ----------------------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.019759570082153628
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  4.4879784276735695
# GPR.kernel.lengthscales  Parameter  Softplus                   True         (1,)     float64  [0.16101731]
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.0483153720905913e-06
# [2020-03-31 16:58:20] INFO: Running GPFlowCheckpoints callback...
# [2020-03-31 16:58:20] INFO: Running GPRPlotSurface callback...
# [2020-03-31 16:58:20] INFO: After 6th iteration:
# 	 number of obj. func. evaluations: 19
# 	 highest score: 6.822127355673395
# 	 highest UCB: 6.965065385265817
# [2020-03-31 16:58:20] INFO: Running PostIterationPlotting callback...
# [2020-03-31 16:58:20] INFO: Exploration step: sampling children in the ternary tree...
# [2020-03-31 16:58:21] INFO: Selecting step: evaluating best leaves...
# [2020-03-31 16:58:21] INFO: Update step: retraining GP model and updating scores...
# [2020-03-31 16:58:21] INFO: Running PostUpdateLogging callback...
# [2020-03-31 16:58:21] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype    value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ----------------------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.1914477853345468
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  3.473001304862386
# GPR.kernel.lengthscales  Parameter  Softplus                   True         (1,)     float64  [0.10565375]
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.0483152941529388e-06
# [2020-03-31 16:58:21] INFO: Running GPFlowCheckpoints callback...
# [2020-03-31 16:58:21] INFO: Running GPRPlotSurface callback...
# [2020-03-31 16:58:21] INFO: After 7th iteration:
# 	 number of obj. func. evaluations: 23
# 	 highest score: 6.822127355673395
# 	 highest UCB: 7.5863081599544016
# [2020-03-31 16:58:21] INFO: Running PostIterationPlotting callback...
# [2020-03-31 16:58:21] INFO: Exploration step: sampling children in the ternary tree...
# [2020-03-31 16:58:22] INFO: Selecting step: evaluating best leaves...
# [2020-03-31 16:58:22] INFO: Update step: retraining GP model and updating scores...
# [2020-03-31 16:58:22] INFO: Running PostUpdateLogging callback...
# [2020-03-31 16:58:22] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype    value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ----------------------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.3111087091292666
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  3.3853761677722747
# GPR.kernel.lengthscales  Parameter  Softplus                   True         (1,)     float64  [0.10490081]
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.0483152590698929e-06
# [2020-03-31 16:58:22] INFO: Running GPFlowCheckpoints callback...
# [2020-03-31 16:58:22] INFO: Running GPRPlotSurface callback...
# [2020-03-31 16:58:23] INFO: After 8th iteration:
# 	 number of obj. func. evaluations: 27
# 	 highest score: 6.822127355673395
# 	 highest UCB: 7.0717763748098825
# [2020-03-31 16:58:23] INFO: Running PostIterationPlotting callback...
# [2020-03-31 16:58:23] INFO: Exploration step: sampling children in the ternary tree...
# [2020-03-31 16:58:23] INFO: Selecting step: evaluating best leaves...
# [2020-03-31 16:58:23] INFO: Update step: retraining GP model and updating scores...
# [2020-03-31 16:58:23] INFO: Running PostUpdateLogging callback...
# [2020-03-31 16:58:23] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype    value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ----------------------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.2693840544617082
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  3.011974679743235
# GPR.kernel.lengthscales  Parameter  Softplus                   True         (1,)     float64  [0.10531179]
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.0483152126625728e-06
# [2020-03-31 16:58:23] INFO: Running GPFlowCheckpoints callback...
# [2020-03-31 16:58:23] INFO: Running GPRPlotSurface callback...
# [2020-03-31 16:58:24] INFO: After 9th iteration:
# 	 number of obj. func. evaluations: 31
# 	 highest score: 6.822127355673395
# 	 highest UCB: 6.375786411525881
# [2020-03-31 16:58:24] INFO: Running PostIterationPlotting callback...
# [2020-03-31 16:58:24] INFO: Exploration step: sampling children in the ternary tree...
# [2020-03-31 16:58:24] INFO: Selecting step: evaluating best leaves...
# [2020-03-31 16:58:24] INFO: Update step: retraining GP model and updating scores...
# [2020-03-31 16:58:25] INFO: Running PostUpdateLogging callback...
# [2020-03-31 16:58:25] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype    value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ----------------------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.26898610096976727
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  3.136405684360732
# GPR.kernel.lengthscales  Parameter  Softplus                   True         (1,)     float64  [0.11201374]
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.0483149224502881e-06
# [2020-03-31 16:58:25] INFO: Running GPFlowCheckpoints callback...
# [2020-03-31 16:58:25] INFO: Running GPRPlotSurface callback...
# [2020-03-31 16:58:25] INFO: After 10th iteration:
# 	 number of obj. func. evaluations: 36
# 	 highest score: 7.880218798440746
# 	 highest UCB: 7.62971639089736
# [2020-03-31 16:58:25] INFO: Running PostIterationPlotting callback...
# [2020-03-31 16:58:32] INFO: Exploration step: sampling children in the ternary tree...
# [2020-03-31 16:58:32] INFO: Selecting step: evaluating best leaves...
# [2020-03-31 16:58:32] INFO: Update step: retraining GP model and updating scores...
# [2020-03-31 16:58:33] INFO: Running PostUpdateLogging callback...
# [2020-03-31 16:58:33] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype    value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ----------------------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.23676298471836404
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  2.9740338613309367
# GPR.kernel.lengthscales  Parameter  Softplus                   True         (1,)     float64  [0.11314123]
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.0483141779347638e-06
# [2020-03-31 16:58:33] INFO: Running GPFlowCheckpoints callback...
# [2020-03-31 16:58:33] INFO: Running GPRPlotSurface callback...
# [2020-03-31 16:58:33] INFO: After 11th iteration:
# 	 number of obj. func. evaluations: 40
# 	 highest score: 8.04056301525883
# 	 highest UCB: 8.036435700253685
# [2020-03-31 16:58:33] INFO: Running PostIterationPlotting callback...
# [2020-03-31 16:58:40] INFO: Exploration step: sampling children in the ternary tree...
# [2020-03-31 16:58:40] INFO: Selecting step: evaluating best leaves...
# [2020-03-31 16:58:40] INFO: Update step: retraining GP model and updating scores...
# [2020-03-31 16:58:41] INFO: Running PostUpdateLogging callback...
# [2020-03-31 16:58:41] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype    value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ---------------------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.24542508589868267
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  3.152068716401917
# GPR.kernel.lengthscales  Parameter  Softplus                   True         (1,)     float64  [0.12050097]
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.048309199694962e-06
# [2020-03-31 16:58:41] INFO: Running GPFlowCheckpoints callback...
# [2020-03-31 16:58:41] INFO: Running GPRPlotSurface callback...
# [2020-03-31 16:58:41] INFO: After 12th iteration:
# 	 number of obj. func. evaluations: 45
# 	 highest score: 8.04056301525883
# 	 highest UCB: 8.105553226529622
# [2020-03-31 16:58:41] INFO: Running PostIterationPlotting callback...
# [2020-03-31 16:58:47] INFO: Exploration step: sampling children in the ternary tree...
# [2020-03-31 16:58:48] INFO: Selecting step: evaluating best leaves...
# [2020-03-31 16:58:48] INFO: Update step: retraining GP model and updating scores...
# [2020-03-31 16:58:49] INFO: Running PostUpdateLogging callback...
# [2020-03-31 16:58:49] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype    value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ----------------------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.1914997630083578
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  3.1638359516958254
# GPR.kernel.lengthscales  Parameter  Softplus                   True         (1,)     float64  [0.12871433]
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.0482615988850796e-06
# [2020-03-31 16:58:49] INFO: Running GPFlowCheckpoints callback...
# [2020-03-31 16:58:49] INFO: Running GPRPlotSurface callback...
# [2020-03-31 16:58:49] INFO: After 13th iteration:
# 	 number of obj. func. evaluations: 52
# 	 highest score: 8.102201204076508
# 	 highest UCB: 8.074071892409297
# [2020-03-31 16:58:49] INFO: Running PostIterationPlotting callback...
# [2020-03-31 16:58:56] INFO: Done. Highest evaluated score: 8.102201204076508
# [2020-03-31 16:58:56] INFO: Running PreFinaliseSave callback...
# [2020-03-31 16:58:56] WARNING: output could not be created: [Errno 17] File exists: 'output'

# %%
# WOHOOO, check the best point
print(best_point)
# and print summary of our trained GPR model
print_summary(opt.gp_surr.gpr_model, fmt="notebook")
# Out:
# GPPoint(normed_coord=array([0.23662551, 0.68518519]), score_mu=8.102201204076508, score_sigma=0.0, score_ucb=0.0, label=<PointLabels.evaluated: 1>)
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                 </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.mean_function.c    </td><td>Parameter</td><td>                </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.1914997630083578    </td></tr>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.1638359516958254    </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[0.12871433]          </td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.0482615988850796e-06</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ### Aftermath
#
# So we can see that the results are the same as before (duh), but, we can see:
# 1. overview table of GPR hyperparameters in the log after each update (thanks to `PostUpdateLogging` callback)
# 2. plots after each iteration (thanks to `PostIterationPlotting` callback)
# 3. saved parameter space and GPR surrogate (thanks to `PreFinaliseSave` callback)
# 4. checkpoints while training the GPR (courtesy of `GPFlowCheckpoints` callback)
#
# but mainly
#
# 5. plots of surrogate mean surface after each update, so we can monitor how the training "helps" the surrogate to get the correct shape (courtesy of our brand new `GPRPlotSurface` callback)

# %%
# cleaning - run after you check the results!
rmtree(plotting_dir)
