# %% [markdown]
# # GPSO optimisation example with callbacks
#
# This notebook shows the usage of callbacks during optimisation for the better experience!

# %%
# imports
import os
import numpy as np
import matplotlib.pyplot as plt
from shutil import rmtree
import logging
from gpflow.utilities import print_summary

from gpso import ParameterSpace, GPSOptimiser, GPRSurrogate
from gpso.optimisation import CallbackTypes, GPSOCallback
from gpso.callbacks import (
    PostIterationPlotting,
    PostUpdateLogging,
    PreFinaliseSave,
    GPFlowCheckpoints,
)
from gpso.utils import set_logger, make_dirs

plt.style.use("seaborn-poster")

# %% [markdown]
# We will use the same objective function as before, so no surprises there.

# %%
# define objective function - compare with paper Fig. 2
def obj(point, offset=0.0, rotate=True):
    x, y = point
    if rotate:
        ct = np.cos(np.pi / 4)
        st = np.sin(np.pi / 4)
        xn = ct * x + st * y
        yn = ct * y - st * x
        x = xn
        y = yn
    return (
        3 * (1 - x) ** 2.0 * np.exp(-(x ** 2) - (y + 1) ** 2)
        - 10 * (x / 5.0 - x ** 3 - y ** 5) * np.exp(-(x ** 2) - y ** 2)
        - 1 / 3 * np.exp(-((x + 1) ** 2) - y ** 2)
        - offset
    )


# bounds of the parameters we will optimise
x_bounds = [-3, 5]
y_bounds = [-3, 3]
# number of points per dimension for plotting
N_POINTS = 120

# %% [markdown]
# Definition of parameter space is the same as previously

# %%
space = ParameterSpace(
    parameter_names=["x", "y"], parameter_bounds=[x_bounds, y_bounds]
)

# %% [markdown]
# Now for the changes!
#
# ### Callbacks
# `pyGPSO` supports so-called callbacks. They are functions which run regularly after some events. Currently there exist 5 types of callbacks:
# * **post-initialise callback**: runs just once, after initialisation of the problem
# * **pre-iteration callback**: runs repeatedly just before the iteration loop
# * **post-iteration callback**: runs repeatedly just after the iteration loop
# * **post-update callback**: runs after each update of GPR
# * **pre-finalise callback**: runs just once, just before the optimisation is finished
#
# `pyGPSO` comes with 4 already defined, hopefully useful, callbacks. However, they are very easy to create for yourself as we will see in a moment! Let's first check the predefined callbacks:

# %% [markdown]
# #### `PostIterationPlotting` callback
# Simple - plots conditional surrogate distribution, marginal parameter distribution and ternary tree after each iteration, so you can visually check the convergence of the algorithm

# %%
plotting_dir = "output"
make_dirs(plotting_dir)

plotting_callback = PostIterationPlotting(
    filename_pattern=os.path.join(plotting_dir, "post_iter_plot"),
    plot_ext=".png",
    gp_mean_limits=[-10, 10],
    gp_var_limits=[0, 5],
    marginal_plot_type="kde",
    marginal_percentile=0.5,  # low percentile - just for showcase
    from_iteration=10,  # from 10th iteration, we do not care about first 10...
)

# %% [markdown]
# #### `PostUpdateLogging` callback
# Even simpler callback - after each GPR update logs the current hyperparameters of GP regressor

# %%
gp_logger = PostUpdateLogging()

# %% [markdown]
# #### `PreFinaliseSave` callback
# This callback saves parameter space (and its state, i.e. leaves) and GPR surrogate together with list of points that were either evaluated or (as centers of leaves) estimated.

# %%
fin_saver = PreFinaliseSave(path=plotting_dir)

# %% [markdown]
# #### `GPFlowCheckpoints` callback
# This callback saves checkpoints of the GPR model after each update. As such it might not be useful, but can be easily altered to provide more functionality, e.g. restoring GPR model on the go.

# %%
checkpoints = GPFlowCheckpoints(path=plotting_dir, max_to_keep=3)

# %% [markdown]
# ### Create your own callback!
# OK, nice, you got me hooked, right? But I do not like your callbacks, I'd like to create my own!
#
# Well, no problemo! Lets say, you want a callback that will plot surface of GPR after each GPR update. Lets start!

# %%
# we will subclass base callback
class GPRPlotSurface(GPSOCallback):
    # define type of callback - post-update
    callback_type = CallbackTypes.post_update

    # do all settings here!
    def __init__(self, path):
        # always super init for a sanity check and validation
        super().__init__()
        self.path = path
        # set plotting data
        x = np.linspace(x_bounds[0], x_bounds[1], N_POINTS)
        y = np.linspace(y_bounds[0], y_bounds[1], N_POINTS)
        x, y = np.meshgrid(x, y)
        self.stk = np.hstack([x.reshape((-1, 1)), y.reshape((-1, 1))])
        self.im_shape = x.shape
        self.counter = 0

    # this will be actually run when a callback is called
    # always only one argument - optimiser class itself
    def run(self, optimiser):
        # always super run for a sanity check and validation
        super().run(optimiser)
        # actual plotting
        plt.figure()
        mean, _ = optimiser.gp_surr.gpflow_model.predict_y(
            optimiser.param_space.normalise_coords(self.stk)
        )
        mean = mean.numpy().reshape(self.im_shape)
        plt.imshow(
            mean, vmax=8.0, vmin=-8.0, cmap=plt.get_cmap("cividis"), origin="lower"
        )
        cbar = plt.colorbar()
        cbar.set_label("Objective-GP")
        plt.title("Surrogate surface")
        plt.savefig(os.path.join(self.path, f"surr_surface_{self.counter}.png"))
        plt.close()
        self.counter += 1


# now we need to init our brand new callback
surr_surface = GPRPlotSurface(path=plotting_dir)

# %% [markdown]
# ### Run with callbacks
# After we initialise our callbacks, we run the optimiser as usual and just pass all callbacks as a list

# %%
opt = GPSOptimiser(
    parameter_space=space,
    gp_surrogate=GPRSurrogate.default(),
    exploration_method="tree",
    exploration_depth=5,
    update_cycle=1,
    budget=50,
    stopping_condition="evaluations",
    n_workers=4,
    callbacks=[plotting_callback, gp_logger, fin_saver, checkpoints, surr_surface],
)

# %%
# log_level INFO: reasonable amount of information on what is happening
# log_level DEBUG: a lot of information on what is happening
set_logger(log_level=logging.INFO)
# run vanilla, with default initialisation and just 1 repetition of objective function (since it's deterministic...)
best_point = opt.run(obj)
# Out:
# [2020-05-13 23:38:18] INFO: Starting 2-dimensional optimisation with budget of 50 objective function evaluations...
# [2020-05-13 23:38:18] INFO: Sampling 2 vertices per dimension within L1 ball of 0.25 of the domain size radius in normalised coordinates using 4 worker(s)...
# [2020-05-13 23:38:19] INFO: Update step: retraining GP model and updating scores...
# [2020-05-13 23:38:21] INFO: Running PostUpdateLogging callback...
# [2020-05-13 23:38:21] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype           value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ------------
# GPR.mean_function.c      Parameter                             True         ()       float64  -0.993932
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64   6.79197
# GPR.kernel.lengthscales  Parameter  Softplus                   True         ()       float64   0.360479
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64   1.04832e-06
# [2020-05-13 23:38:21] INFO: Running GPFlowCheckpoints callback...
# [2020-05-13 23:38:21] INFO: Running GPRPlotSurface callback...
# [2020-05-13 23:38:21] INFO: Exploration step: sampling children in the ternary tree...
# [2020-05-13 23:38:21] INFO: Selecting step: evaluating best leaves...
# [2020-05-13 23:38:21] INFO: Update step: retraining GP model and updating scores...
# [2020-05-13 23:38:22] INFO: Running PostUpdateLogging callback...
# [2020-05-13 23:38:22] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype           value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ------------
# GPR.mean_function.c      Parameter                             True         ()       float64  -0.468473
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64   6.18968
# GPR.kernel.lengthscales  Parameter  Softplus                   True         ()       float64   0.331732
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64   1.04832e-06
# [2020-05-13 23:38:22] INFO: Running GPFlowCheckpoints callback...
# [2020-05-13 23:38:22] INFO: Running GPRPlotSurface callback...
# [2020-05-13 23:38:22] INFO: After 1th iteration:
# 	 number of obj. func. evaluations: 6
# 	 highest score: 2.019346080880167
# 	 highest UCB: 0.5464137300581137
# [2020-05-13 23:38:22] INFO: Running PostIterationPlotting callback...
# [2020-05-13 23:38:22] INFO: Exploration step: sampling children in the ternary tree...
# [2020-05-13 23:38:22] INFO: Selecting step: evaluating best leaves...
# [2020-05-13 23:38:22] INFO: Update step: retraining GP model and updating scores...
# [2020-05-13 23:38:22] INFO: Running PostUpdateLogging callback...
# [2020-05-13 23:38:22] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype           value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ------------
# GPR.mean_function.c      Parameter                             True         ()       float64  -0.585627
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64   4.64646
# GPR.kernel.lengthscales  Parameter  Softplus                   True         ()       float64   0.29387
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64   1.04832e-06
# [2020-05-13 23:38:22] INFO: Running GPFlowCheckpoints callback...
# [2020-05-13 23:38:22] INFO: Running GPRPlotSurface callback...
# [2020-05-13 23:38:23] INFO: After 2th iteration:
# 	 number of obj. func. evaluations: 7
# 	 highest score: 2.019346080880167
# 	 highest UCB: 3.883138246958854
# [2020-05-13 23:38:23] INFO: Running PostIterationPlotting callback...
# [2020-05-13 23:38:23] INFO: Exploration step: sampling children in the ternary tree...
# [2020-05-13 23:38:23] INFO: Selecting step: evaluating best leaves...
# [2020-05-13 23:38:23] INFO: Update step: retraining GP model and updating scores...
# [2020-05-13 23:38:23] INFO: Running PostUpdateLogging callback...
# [2020-05-13 23:38:23] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype           value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ------------
# GPR.mean_function.c      Parameter                             True         ()       float64  -0.228637
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64   2.58129
# GPR.kernel.lengthscales  Parameter  Softplus                   True         ()       float64   0.186038
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64   1.04832e-06
# [2020-05-13 23:38:23] INFO: Running GPFlowCheckpoints callback...
# [2020-05-13 23:38:23] INFO: Running GPRPlotSurface callback...
# [2020-05-13 23:38:24] INFO: After 3th iteration:
# 	 number of obj. func. evaluations: 9
# 	 highest score: 2.019346080880167
# 	 highest UCB: 3.5729359051551643
# [2020-05-13 23:38:24] INFO: Running PostIterationPlotting callback...
# [2020-05-13 23:38:24] INFO: Exploration step: sampling children in the ternary tree...
# [2020-05-13 23:38:24] INFO: Selecting step: evaluating best leaves...
# [2020-05-13 23:38:24] INFO: Update step: retraining GP model and updating scores...
# [2020-05-13 23:38:24] INFO: Running PostUpdateLogging callback...
# [2020-05-13 23:38:24] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype           value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  ------------
# GPR.mean_function.c      Parameter                             True         ()       float64  -0.176456
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64   1.90153
# GPR.kernel.lengthscales  Parameter  Softplus                   True         ()       float64   0.131461
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64   1.04832e-06
# [2020-05-13 23:38:24] INFO: Running GPFlowCheckpoints callback...
# [2020-05-13 23:38:24] INFO: Running GPRPlotSurface callback...
# [2020-05-13 23:38:24] INFO: After 4th iteration:
# 	 number of obj. func. evaluations: 12
# 	 highest score: 2.019346080880167
# 	 highest UCB: 3.259899162869818
# [2020-05-13 23:38:24] INFO: Running PostIterationPlotting callback...
# [2020-05-13 23:38:24] INFO: Exploration step: sampling children in the ternary tree...
# [2020-05-13 23:38:25] INFO: Selecting step: evaluating best leaves...
# [2020-05-13 23:38:25] INFO: Update step: retraining GP model and updating scores...
# [2020-05-13 23:38:25] INFO: Running PostUpdateLogging callback...
# [2020-05-13 23:38:25] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype          value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  -----------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.0702639
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  4.94887
# GPR.kernel.lengthscales  Parameter  Softplus                   True         ()       float64  0.148167
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.04832e-06
# [2020-05-13 23:38:25] INFO: Running GPFlowCheckpoints callback...
# [2020-05-13 23:38:25] INFO: Running GPRPlotSurface callback...
# [2020-05-13 23:38:25] INFO: After 5th iteration:
# 	 number of obj. func. evaluations: 15
# 	 highest score: 6.822127355673395
# 	 highest UCB: 7.162332354239722
# [2020-05-13 23:38:25] INFO: Running PostIterationPlotting callback...
# [2020-05-13 23:38:25] INFO: Exploration step: sampling children in the ternary tree...
# [2020-05-13 23:38:26] INFO: Selecting step: evaluating best leaves...
# [2020-05-13 23:38:26] INFO: Update step: retraining GP model and updating scores...
# [2020-05-13 23:38:26] INFO: Running PostUpdateLogging callback...
# [2020-05-13 23:38:26] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype          value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  -----------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.0197596
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  4.48798
# GPR.kernel.lengthscales  Parameter  Softplus                   True         ()       float64  0.161017
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.04832e-06
# [2020-05-13 23:38:26] INFO: Running GPFlowCheckpoints callback...
# [2020-05-13 23:38:26] INFO: Running GPRPlotSurface callback...
# [2020-05-13 23:38:27] INFO: After 6th iteration:
# 	 number of obj. func. evaluations: 19
# 	 highest score: 6.822127355673395
# 	 highest UCB: 6.965065385265779
# [2020-05-13 23:38:27] INFO: Running PostIterationPlotting callback...
# [2020-05-13 23:38:27] INFO: Exploration step: sampling children in the ternary tree...
# [2020-05-13 23:38:27] INFO: Selecting step: evaluating best leaves...
# [2020-05-13 23:38:27] INFO: Update step: retraining GP model and updating scores...
# [2020-05-13 23:38:27] INFO: Running PostUpdateLogging callback...
# [2020-05-13 23:38:27] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype          value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  -----------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.191448
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  3.473
# GPR.kernel.lengthscales  Parameter  Softplus                   True         ()       float64  0.105654
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.04832e-06
# [2020-05-13 23:38:27] INFO: Running GPFlowCheckpoints callback...
# [2020-05-13 23:38:27] INFO: Running GPRPlotSurface callback...
# [2020-05-13 23:38:28] INFO: After 7th iteration:
# 	 number of obj. func. evaluations: 23
# 	 highest score: 6.822127355673395
# 	 highest UCB: 7.586308159954069
# [2020-05-13 23:38:28] INFO: Running PostIterationPlotting callback...
# [2020-05-13 23:38:28] INFO: Exploration step: sampling children in the ternary tree...
# [2020-05-13 23:38:28] INFO: Selecting step: evaluating best leaves...
# [2020-05-13 23:38:28] INFO: Update step: retraining GP model and updating scores...
# [2020-05-13 23:38:29] INFO: Running PostUpdateLogging callback...
# [2020-05-13 23:38:29] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype          value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  -----------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.311109
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  3.38538
# GPR.kernel.lengthscales  Parameter  Softplus                   True         ()       float64  0.104901
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.04832e-06
# [2020-05-13 23:38:29] INFO: Running GPFlowCheckpoints callback...
# [2020-05-13 23:38:29] INFO: Running GPRPlotSurface callback...
# [2020-05-13 23:38:29] INFO: After 8th iteration:
# 	 number of obj. func. evaluations: 27
# 	 highest score: 6.822127355673395
# 	 highest UCB: 7.0717763748098275
# [2020-05-13 23:38:29] INFO: Running PostIterationPlotting callback...
# [2020-05-13 23:38:29] INFO: Exploration step: sampling children in the ternary tree...
# [2020-05-13 23:38:29] INFO: Selecting step: evaluating best leaves...
# [2020-05-13 23:38:29] INFO: Update step: retraining GP model and updating scores...
# [2020-05-13 23:38:30] INFO: Running PostUpdateLogging callback...
# [2020-05-13 23:38:30] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype          value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  -----------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.269384
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  3.01197
# GPR.kernel.lengthscales  Parameter  Softplus                   True         ()       float64  0.105312
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.04832e-06
# [2020-05-13 23:38:30] INFO: Running GPFlowCheckpoints callback...
# [2020-05-13 23:38:30] INFO: Running GPRPlotSurface callback...
# [2020-05-13 23:38:30] INFO: After 9th iteration:
# 	 number of obj. func. evaluations: 31
# 	 highest score: 6.822127355673395
# 	 highest UCB: 6.375786411525929
# [2020-05-13 23:38:30] INFO: Running PostIterationPlotting callback...
# [2020-05-13 23:38:30] INFO: Exploration step: sampling children in the ternary tree...
# [2020-05-13 23:38:31] INFO: Selecting step: evaluating best leaves...
# [2020-05-13 23:38:31] INFO: Update step: retraining GP model and updating scores...
# [2020-05-13 23:38:31] INFO: Running PostUpdateLogging callback...
# [2020-05-13 23:38:31] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype          value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  -----------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.268986
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  3.13641
# GPR.kernel.lengthscales  Parameter  Softplus                   True         ()       float64  0.112014
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.04831e-06
# [2020-05-13 23:38:31] INFO: Running GPFlowCheckpoints callback...
# [2020-05-13 23:38:31] INFO: Running GPRPlotSurface callback...
# [2020-05-13 23:38:31] INFO: After 10th iteration:
# 	 number of obj. func. evaluations: 36
# 	 highest score: 7.880218798440746
# 	 highest UCB: 7.6297163908975705
# [2020-05-13 23:38:31] INFO: Running PostIterationPlotting callback...
# [2020-05-13 23:38:38] INFO: Exploration step: sampling children in the ternary tree...
# [2020-05-13 23:38:39] INFO: Selecting step: evaluating best leaves...
# [2020-05-13 23:38:39] INFO: Update step: retraining GP model and updating scores...
# [2020-05-13 23:38:39] INFO: Running PostUpdateLogging callback...
# [2020-05-13 23:38:39] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype          value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  -----------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.236763
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  2.97403
# GPR.kernel.lengthscales  Parameter  Softplus                   True         ()       float64  0.113141
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.04831e-06
# [2020-05-13 23:38:39] INFO: Running GPFlowCheckpoints callback...
# [2020-05-13 23:38:39] INFO: Running GPRPlotSurface callback...
# [2020-05-13 23:38:39] INFO: After 11th iteration:
# 	 number of obj. func. evaluations: 40
# 	 highest score: 8.04056301525883
# 	 highest UCB: 8.036435700251587
# [2020-05-13 23:38:39] INFO: Running PostIterationPlotting callback...
# [2020-05-13 23:38:46] INFO: Exploration step: sampling children in the ternary tree...
# [2020-05-13 23:38:47] INFO: Selecting step: evaluating best leaves...
# [2020-05-13 23:38:47] INFO: Update step: retraining GP model and updating scores...
# [2020-05-13 23:38:47] INFO: Running PostUpdateLogging callback...
# [2020-05-13 23:38:47] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype          value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  -----------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.245425
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  3.15207
# GPR.kernel.lengthscales  Parameter  Softplus                   True         ()       float64  0.120501
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.04831e-06
# [2020-05-13 23:38:47] INFO: Running GPFlowCheckpoints callback...
# [2020-05-13 23:38:47] INFO: Running GPRPlotSurface callback...
# [2020-05-13 23:38:47] INFO: After 12th iteration:
# 	 number of obj. func. evaluations: 45
# 	 highest score: 8.04056301525883
# 	 highest UCB: 8.105553226530422
# [2020-05-13 23:38:47] INFO: Running PostIterationPlotting callback...
# [2020-05-13 23:38:54] INFO: Exploration step: sampling children in the ternary tree...
# [2020-05-13 23:38:54] INFO: Selecting step: evaluating best leaves...
# [2020-05-13 23:38:54] INFO: Update step: retraining GP model and updating scores...
# [2020-05-13 23:38:55] INFO: Running PostUpdateLogging callback...
# [2020-05-13 23:38:55] INFO: GPR summary:
# name                     class      transform         prior    trainable    shape    dtype          value
# -----------------------  ---------  ----------------  -------  -----------  -------  -------  -----------
# GPR.mean_function.c      Parameter                             True         ()       float64  0.1915
# GPR.kernel.variance      Parameter  Softplus                   True         ()       float64  3.16384
# GPR.kernel.lengthscales  Parameter  Softplus                   True         ()       float64  0.128714
# GPR.likelihood.variance  Parameter  Softplus + Shift           True         ()       float64  1.04826e-06
# [2020-05-13 23:38:55] INFO: Running GPFlowCheckpoints callback...
# [2020-05-13 23:38:55] INFO: Running GPRPlotSurface callback...
# [2020-05-13 23:38:55] INFO: After 13th iteration:
# 	 number of obj. func. evaluations: 52
# 	 highest score: 8.102201204076508
# 	 highest UCB: 8.074071892409629
# [2020-05-13 23:38:55] INFO: Running PostIterationPlotting callback...
# [2020-05-13 23:39:02] INFO: Done. Highest evaluated score: 8.102201204076508
# [2020-05-13 23:39:02] INFO: Running PreFinaliseSave callback...
# [2020-05-13 23:39:02] WARNING: output could not be created: [Errno 17] File exists: 'output'

# %%
# WOHOOO, check the best point
print(best_point)
# and print summary of our trained GPR model
print_summary(opt.gp_surr.gpflow_model, fmt="notebook")
# Out:
# GPPoint(normed_coord=array([0.23662551, 0.68518519]), score_mu=8.102201204076508, score_sigma=0.0, score_ucb=0.0, label=<PointLabels.evaluated: 1>)
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th style="text-align: right;">      value</th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.mean_function.c    </td><td>Parameter</td><td>                </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td style="text-align: right;">0.1915     </td></tr>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td style="text-align: right;">3.16384    </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td style="text-align: right;">0.128714   </td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td style="text-align: right;">1.04826e-06</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ### Aftermath
#
# So we can see that the results are the same as before (duh), but, we can see:
# 1. overview table of GPR hyperparameters in the log after each update (thanks to `PostUpdateLogging` callback)
# 2. plots after each iteration (thanks to `PostIterationPlotting` callback)
# 3. saved parameter space and GPR surrogate (thanks to `PreFinaliseSave` callback)
# 4. checkpoints while training the GPR (courtesy of `GPFlowCheckpoints` callback)
#
# but mainly
#
# 5. plots of surrogate mean surface after each update, so we can monitor how the training "helps" the surrogate to get the correct shape (courtesy of our brand new `GPRPlotSurface` callback)

# %%
# cleaning - run after you check the results!
rmtree(plotting_dir)
